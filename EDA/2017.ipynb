# %%
### Imports
import pandas as pd

# %%
### Load the dataset
df2017 = pd.read_csv('https://raw.githubusercontent.com/Frans-Grau/P5-Forecasting/main/Datasets/df2017.csv')
df2017.head()
# Out:
#    Unnamed: 0     FL_DATE OP_CARRIER ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  \
# 0           0  2017-01-01         AA    JFK  LAX           800     831.0
# 1           1  2017-01-01         AA    LAX  JFK           900     934.0
# 2           2  2017-01-01         AA    LAX  JFK          1130    1221.0
# 3           7  2017-01-01         AA    JFK  SFO           700     656.0
# 4           8  2017-01-01         AA    LAX  JFK          2100    2100.0
#
#    DEP_DELAY  CRS_ARR_TIME  ARR_TIME  CANCELLED  DIVERTED  AIR_TIME  DISTANCE
# 0       31.0          1142    1209.0        0.0       0.0     347.0    2475.0
# 1       34.0          1727    1809.0        0.0       0.0     289.0    2475.0
# 2       51.0          1958    2040.0        0.0       0.0     284.0    2475.0
# 3       -4.0          1045    1023.0        0.0       0.0     362.0    2586.0
# 4        0.0           527     457.0        0.0       0.0     272.0    2475.0
