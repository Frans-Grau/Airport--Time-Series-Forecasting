# %%
### Imports
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
### Website
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.flylax.com/lax-dining-and-shopping')

# %%
all_after = list(map(lambda name: name.text, driver.find_elements_by_class_name('Dining-sub-section')))
data_after = pd.DataFrame(all_after)
data_after.rename(columns={0:'Name'}, inplace=True)
data_after['Name'] = data_after['Name'].apply(lambda x: x.split("\n")[0])
data_after['Location'] = 'After Security'
data_after.head()
# Out:
#                      Name        Location
# 0       800 Degrees Pizza  After Security
# 1                A/K Blvd  After Security
# 2                A/K Blvd  After Security
# 3               Ace Tacos  After Security
# 4  Ashland Hill (and Bar)  After Security

# %%
all_before = list(map(lambda name: name.text, driver.find_elements_by_class_name('Dining-sub-section')))
data_before = pd.DataFrame(all_before)
data_before.rename(columns={0:'Name'}, inplace=True)
data_before['Name'] = data_before['Name'].apply(lambda x: x.split("\n")[0])
data_before['Location'] = 'Before Security'
data_before.head()
# Out:
#                 Name         Location
# 0  Asian Street Eats  Before Security
# 1     Dunkin' Donuts  Before Security
# 2   Earl of Sandwich  Before Security
# 3              Jamba  Before Security
# 4          Pinkberry  Before Security

# %%
LAX_restaurants = pd.concat([data_before, data_after])
# LAX_restaurants.to_csv('LAX-Restaurants.csv')

# %%
LAX_restaurants
# Out:
#                        Name         Location
# 0         Asian Street Eats  Before Security
# 1            Dunkin' Donuts  Before Security
# 2          Earl of Sandwich  Before Security
# 3                     Jamba  Before Security
# 4                 Pinkberry  Before Security
# ..                      ...              ...
# 94                Vino Volo   After Security
# 95         Wahoos Fish Taco   After Security
# 96        Wetzel's / Quench   After Security
# 97    Wolfgang Puck Express   After Security
# 98  Wpizza by Wolfgang Puck   After Security
#
# [112 rows x 2 columns]

# %%
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Dunkin' Donuts (kiosk)"], "Dunkin' Donuts")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Starbucks (Arrivals)"], "Starbucks")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Starbucks'"], "Starbucks")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Ashland Hill (and Bar)"], "Ashland Hill")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Carry on Coffee & Market Place"], "Carry On Marketplace")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Dunkin Donuts"], "Dunkin' Donuts")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Homeboy"], "Homeboy Cafe")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["LA Life Market Kiosk"], "LA Life Quick Market")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace([""], "LA Life Quick Market")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["LA Life"], "LA Life Quick Market")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Loteria!! Grill"], "Loteria! Grill")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Rock & Brews Concert Bar and Grill"], "Rock & Brews Concert Bar & Grill")
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["Starbucks Evenings"], "Starbucks") 
LAX_restaurants['Name'] = LAX_restaurants['Name'].replace(["The Coffee Bean and Tea Leaf"], "The Coffee Bean & Tea Leaf")

# %%
LAX_restaurants.to_csv('LAX-Restaurants.csv')

# %%
LAX_restaurants.Name.to_list()
# Out:
# ['Asian Street Eats',
#  "Dunkin' Donuts",
#  'Earl of Sandwich',
#  'Jamba',
#  'Pinkberry',
#  'Planet Hollywood',
#  'Starbucks',
#  'Starbucks',
#  'Starbucks',
#  'The Coffee Bean & Tea Leaf',
#  'The Coffee Bean & Tea Leaf',
#  'The Coffee Bean & Tea Leaf',
#  'WPizza by Wolfgang Puck',
#  '800 Degrees Pizza',
#  'A/K Blvd',
#  'A/K Blvd',
#  'Ace Tacos',
#  'Ashland Hill',
#  'Ashland Hill',
#  'B Grill By BOA Steakhouse',
#  'Barneys Beanery',
#  'beaming',
#  "Beecher's Handmade Cheese",
#  'Betcha Burger',
#  'BLD',
#  'BLU2o',
#  'Border Grill',
#  'Breeze',
#  'BUILT (Custom Burgers)',
#  'Burger King',
#  'California Pizza Kitchen',
#  'California Pizza Kitchen',
#  'Campanile',
#  "Carl's Jr",
#  'Carry On Marketplace',
#  'Carry On Marketplace',
#  'Chaya Sushi',
#  'Chick-fil-A',
#  'Coffee Corner',
#  'Deli & Co.',
#  'Donburi Bistro',
#  "Dunkin' Donuts",
#  'Earthbar',
#  'Earthbar',
#  'Eat, Drink, Fly',
#  'Einstein Bros. Bagels',
#  'Engine Co. No. 28',
# ...
